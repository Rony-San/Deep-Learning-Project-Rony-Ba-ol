# %% [markdown]
# <a href="https://colab.research.google.com/github/Rony-San/Deep-Learning-Project-Rony-Ba-ol/blob/main/01_exploraci%C3%B3n_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (2.137.0)
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.147.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.27.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.19.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.24.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.1.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2024.8.30)
# Downloading google_api_python_client-2.147.0-py2.py3-none-any.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 59.4 MB/s eta 0:00:00
# Installing collected packages: google-api-python-client
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.137.0
#     Uninstalling google-api-python-client-2.137.0:
#       Successfully uninstalled google-api-python-client-2.137.0
# Successfully installed google-api-python-client-2.147.0

# %%
from google.colab import auth
from googleapiclient.discovery import build
import gdown
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Autenticar y permitir acceso a Google Drive
auth.authenticate_user()
drive_service = build('drive', 'v3')
folder_id = '1P9bgzza9OODgJKLQIV1fx-CLqGK3OUG5'


results = drive_service.files().list(q=f"'{folder_id}' in parents",
                                     fields="files(id, name)").execute()
items = results.get('files', [])

# Listar los archivos
if not items:
    print('No files found.')
else:
    print('Files found:')
    for item in items:
        print(f'{item["name"]} ({item["id"]})')

# Crear una carpeta local para almacenar las imágenes
if not os.path.exists('pokemon_images'):
    os.makedirs('pokemon_images')

# Descargar y mostrar las primeras 5 imágenes
for item in items[:5]:  # Cambia el rango según cuántas imágenes quieras descargar
    image_name = item["name"]
    file_id = item["id"]

    # Descargar usando gdown
    print(f'Descargando {image_name}')
    gdown.download(f"https://drive.google.com/uc?id={file_id}", f"pokemon_images/{image_name}", quiet=False)

    # Mostrar la imagen descargada
    img = mpimg.imread(f"pokemon_images/{image_name}")
    plt.figure()
    plt.imshow(img)
    plt.title(image_name)
    plt.axis('off')  # Ocultar los ejes
    plt.show()
# Out:
# Files found:
# xatu.png (1Urq4Tl_oYizXBXitJAYHvnKjiF4SbP5G)
# wooper.png (1AS0seBj1sxek_uUbR53GLafo6eg3wh15)
# zygarde-50.png (19OlDqGIdA-XAN_oKd-aV2ruykJtjwPKu)
# zweilous.png (1vitsyAGR4NC-vzKtb5WoBG-AvpPF2CVm)
# yanma.png (1vgH196XFfkot2xhX3hd3ZI30QkTHJ0mO)
# yanmega.png (1P9oWrpD7SVgcjHWCbf9AQFXxaubY-Ran)
# wynaut.png (15HxaiblEvS7w6xSZAFma3OTM3u6-4nTx)
# wormadam-plant.png (1U1eKYsCiU-14YTr2dqCMgupCkYXTobDr)
# yungoos.png (1dSvBDNPkzAsP9UdUYqrCMYWmfAD3p1dA)
# zoroark.png (1rznmxFNCpTlUJsmg_uJPUxnjQqKufJDB)
# zebstrika.png (1n6UBHJxzj-C_50BbO8VjirCTTl4VyKth)
# zigzagoon.png (1NtkX0T2BwdBdIr7V4aV9vrUMvHa8IJUU)
# zangoose.png (1WypgdV0ZQ7nkEtPX49YoSz98WmuLB2E7)
# zeraora.png (1wdNFePDK5-6kMD0yBUUaydC-jXkRL8b2)
# yveltal.png (1ma7Drib2naquQdsH654XhBjMW6jbs8sj)
# zekrom.png (1DgL-LU9WwM0lmX96ApmB5XlQrswTkmpC)
# zubat.png (1OU21w4SXZPZrNt4dBPHBKMnWbP6gDAXT)
# xurkitree.png (1NBAyqp8WDZdnbv-8axhYrEfYndIb2hBU)
# xerneas.png (1MWR5JEY-iQCtqoWVsZHSTD6o0UG7qSdt)
# yamask.png (1fJyimB7ZoCEq8xQGWqap9VzMQZVhLCsA)
# zorua.png (1-NabOJi7BsCPG3h4h2ho6p8Hh7o7M94M)
# zapdos.png (1CsACPe7MUZZFBcjs0U-zGgxlVR1xiJP2)
# wurmple.png (1giJG7RSo5c36mFlNMj0PoPaIMT6YSIsE)
# swoobat.png (1YdgMCu6pGAfZuSu_2lPu2uuX-QfCMyh5)
# throh.png (1mWB4dQb68CZEUnHa7riTF5IEA5pPGMHh)
# swirlix.png (1-3pm48_EFglyXtYIl_k0c0Z-edblslxh)
# tornadus-incarnate.png (122-0FfsQxmSZBwe2Tp92IcuyXhxRApTr)
# vaporeon.png (112GC-UFIG0xDiamoYHrbgZUHvkFUrHKH)
# wailmer.png (10YB7ulac4aXkBHjH-g8rXfgSOiEH8jgf)
# weezing.png (18wZy5Uf0vezIQkHlk35Ys-OdPBcwqB3d)
# torchic.png (1e6j7dNmXjuFa2FASez4aTt1c-ppcZmFN)
# unown.png (1Cph0lCSrP8Ok3HChWfgsE5dUPreiO9zz)
# vulpix.png (1Ak1H9PR_-JeF4vxSsU-3pSaXXVLETJBh)
# tentacruel.png (1mMa4vfl9Iyb9t1s_GzWTRfY-8BV0j4uU)
# victreebel.png (1l2qmOHVzeCVV0FhTYUQzcpopE2hstXgE)
# tapu-bulu.png (1rkeU04jC34HOYFJOStp8Q0lWIIIALJFH)
# togekiss.png (1NQHn-96xjFpaihu0ht7denUNiA1iCBXU)
# toxicroak.png (1gQYVU_-y0KUDiKsr0S337KRM1y3zatXj)
# vullaby.png (1RYZdmrpeKRC7G2fHvlmUmbb76DGezOXb)
# torterra.png (1n2jut9ob44Cym2a1iB2dI6bhGwT9tR9L)
# teddiursa.png (1YJyXIaa7B48U8XDuLjiAiigco9HmOQTa)
# weedle.png (1Pnpk77XdTw430_XzY28Pyl2b0H4NoYMG)
# turtonator.png (1OClb11cuIov1LMRwdMmlyeU4kwQX287H)
# wobbuffet.png (1oRTZUw3YjsXJTJ9q0M4TQzY-bSLPwlYm)
# tyrunt.png (1PcB-ttN_v6gBFxCrifjXN-Tqq8_URoQc)
# tangela.png (1-wNRwdv0d79QA98Es6ZebF3srKiP2bFl)
# taillow.png (1dC_91SBXOf2gghVphgsaS6lt3KGqRiAs)
# togedemaru.png (1HEqHjKQLrk0m7i6s22u4fNiGf0tIEr9X)
# vileplume.png (1wEcMxND9iFKrLKh09BjMMGEQ5hJ_Zbf7)
# trumbeak.png (1d78Iv69-7KWgZjpLgLf4wwH5rsjyLkyh)
# trubbish.png (1bzLdUA31u9wnGvks62rFhYkpqkUsiswT)
# whirlipede.png (1he-pl0nhbJGBL3lnEpyD_IY-Eou-lcVv)
# torracat.png (170WVHwviVbcgOQc47FvZIMvJn9koISbc)
# vigoroth.png (17uWL2gK5tLSlp6mvl5sdpSl_zyjKDo5Z)
# tepig.png (1LiNs1JFBybBJQmvHASLO28MnUTN5-UOB)
# type-null.png (1M0JKIq0uV_DI6pMRSuv7je-FEMjxzcts)
# virizion.png (1ymPJwSxm_Fyi30GMYxqIVFwt7dMf0c7J)
# wigglytuff.png (197XjQ7lT35M5bk25xrhXjsiRQxJZSJtg)
# wartortle.png (14NgcU4LwaRpW5XpMW9Mfurtm-xQux6VL)
# timburr.png (1vfd1rQ1vTSa2DpzLSwAy7NtSxQoADUZc)
# tyrogue.png (1UL6NbkloxJJqJH7rXnAJT0EOqGfC3WaI)
# To: /content/pokemon_images/xatu.png
# 100%|██████████| 3.93k/3.93k [00:00<00:00, 11.0MB/s]
# Descargando wooper.png
# Downloading...
# From: https://drive.google.com/uc?id=1AS0seBj1sxek_uUbR53GLafo6eg3wh15
# To: /content/pokemon_images/wooper.png
# 100%|██████████| 2.55k/2.55k [00:00<00:00, 4.98MB/s]
# Descargando zygarde-50.png
# Downloading...
# From: https://drive.google.com/uc?id=19OlDqGIdA-XAN_oKd-aV2ruykJtjwPKu
# To: /content/pokemon_images/zygarde-50.png
# 100%|██████████| 7.61k/7.61k [00:00<00:00, 13.4MB/s]
# Descargando zweilous.png
# Downloading...
# From: https://drive.google.com/uc?id=1vitsyAGR4NC-vzKtb5WoBG-AvpPF2CVm
# To: /content/pokemon_images/zweilous.png
# 100%|██████████| 5.19k/5.19k [00:00<00:00, 10.3MB/s]
# Descargando yanma.png
# Downloading...
# From: https://drive.google.com/uc?id=1vgH196XFfkot2xhX3hd3ZI30QkTHJ0mO
# To: /content/pokemon_images/yanma.png
# 100%|██████████| 3.82k/3.82k [00:00<00:00, 7.29MB/s]

# %%
import gdown

# Enlace directo al archivo en Google Drive
file_url = 'https://drive.google.com/uc?id=1evrRxE3NlCL-wuoQrQAaHXwEKZHC2RzD'
output = 'pokemon_dataset.svc'

# Descargar el archivo
gdown.download(file_url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1evrRxE3NlCL-wuoQrQAaHXwEKZHC2RzD
# To: /content/pokemon_dataset.svc
# 100%|██████████| 17.1k/17.1k [00:00<00:00, 27.0MB/s]
# 'pokemon_dataset.svc'

# %%
import pandas as pd

# Leer el archivo como un CSV
df = pd.read_csv('pokemon_dataset.svc')

# Mostrar las primeras filas del dataset
print(df.head())
# Out:
#          Name  Type1   Type2   Evolution
# 0   bulbasaur  Grass  Poison     ivysaur
# 1     ivysaur  Grass  Poison    venusaur
# 2    venusaur  Grass  Poison         NaN
# 3  charmander   Fire     NaN  charmeleon
# 4  charmeleon   Fire     NaN   charizard

# %%
# Mostrar información básica sobre el dataset
print(df.info())

# Describir estadísticamente las columnas numéricas
print(df.describe())

# Verificar valores nulos
print(df.isnull().sum())

# Mostrar la distribución de los tipos de Pokémon (Type1)
print(df['Type1'].value_counts())

# Graficar algunas distribuciones de las columnas
import matplotlib.pyplot as plt
import seaborn as sns

# Graficar la distribución de los tipos de Pokémon
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Type1')
plt.title('Distribution of Pokemon Types (Type1)')
plt.xticks(rotation=90)
plt.show()

# Graficar la relación entre Type1 y Evolution
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Type1', hue='Evolution')
plt.title('Evolution by Pokemon Type')
plt.xticks(rotation=90)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 809 entries, 0 to 808
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       809 non-null    object
#  1   Type1      809 non-null    object
#  2   Type2      405 non-null    object
#  3   Evolution  32 non-null     object
# dtypes: object(4)
# memory usage: 25.4+ KB
# None
#              Name  Type1   Type2 Evolution
# count         809    809     405        32
# unique        809     18      18        32
# top     bulbasaur  Water  Flying   ivysaur
# freq            1    114      95         1
# Name           0
# Type1          0
# Type2        404
# Evolution    777
# dtype: int64
# Type1
# Water       114
# Normal      105
# Grass        78
# Bug          72
# Fire         53
# Psychic      53
# Rock         46
# Electric     40
# Poison       34
# Ground       32
# Dark         29
# Fighting     29
# Ghost        27
# Dragon       27
# Steel        26
# Ice          23
# Fairy        18
# Flying        3
# Name: count, dtype: int64
